# %%
import pandas as pd

# %%
df = pd.read_csv('../data/Titanic-Dataset.csv')

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.head(15)
# Out:
#     PassengerId  Survived  Pclass  \
# 0             1         0       3
# 1             2         1       1
# 2             3         1       3
# 3             4         1       1
# 4             5         0       3
# 5             6         0       3
# 6             7         0       1
# 7             8         0       3
# 8             9         1       3
# 9            10         1       2
# 10           11         1       3
# 11           12         1       1
# 12           13         0       3
# 13           14         0       3
# 14           15         0       3
#
#                                                  Name     Sex   Age  SibSp  \
# 0                             Braund, Mr. Owen Harris    male  22.0      1
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                              Heikkinen, Miss. Laina  female  26.0      0
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df.sample()
# Out:
#      PassengerId  Survived  Pclass  \
# 486          487         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 486  Hoyt, Mrs. Frederick Maxfield (Jane Anne Forby)  female  35.0      1
#
#      Parch Ticket  Fare Cabin Embarked
# 486      0  19943  90.0   C93        S

# %%
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 594          595         0       2
# 247          248         1       2
# 544          545         0       1
# 408          409         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 594                            Chapman, Mr. John Henry    male  37.0      1
# 247                    Hamalainen, Mrs. William (Anna)  female  24.0      0
# 544                         Douglas, Mr. Walter Donald    male  50.0      1
# 408                  Birkeland, Mr. Hans Martin Monsen    male  21.0      0
#
#      Parch       Ticket      Fare Cabin Embarked
# 1        0     PC 17599   71.2833   C85        C
# 594      0  SC/AH 29037   26.0000   NaN        S
# 247      2       250649   14.5000   NaN        S
# 544      0     PC 17761  106.4250   C86        C
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# statistics of entire dataset without the string objects
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# to check more details on a single column
df.Survived.describe()
# Out:
# count    891.000000
# mean       0.383838
# std        0.486592
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        1.000000
# Name: Survived, dtype: float64

# %%
# to get statistics about 2 or more columns
df[['Survived', 'Pclass']].describe()
# Out:
#          Survived      Pclass
# count  891.000000  891.000000
# mean     0.383838    2.308642
# std      0.486592    0.836071
# min      0.000000    1.000000
# 25%      0.000000    2.000000
# 50%      0.000000    3.000000
# 75%      1.000000    3.000000
# max      1.000000    3.000000

# %%
# mean  or any statistical function like mean, median, mode, std only works with numerical values, 
df.Survived.mean()
# Out:
# np.float64(0.3838383838383838)

# %%
df.Pclass.median()
# Out:
# np.float64(3.0)

# %%
df.Age.std()
# Out:
# np.float64(14.526497332334042)

# %%
df.Age.mean()
# Out:
# np.float64(29.69911764705882)

# %%
df.describe(include='O')
# Out:
#                        Name   Sex  Ticket Cabin Embarked
# count                   891   891     891   204      889
# unique                  891     2     681   147        3
# top     Dooley, Mr. Patrick  male  347082    G6        S
# freq                      1   577       7     4      644

# %%
# gives out the data size by rows, columns
df.shape
# Out:
# (891, 12)

# %%
rows = df.shape[0]
rows
# Out:
# 891

# %%
columns = df.shape[1]
columns
# Out:
# 12

# %%
df.shape[1]
# Out:
# 12

# %%
# dot notation returns a series
df.Survived.head(3)
# Out:
# 0    0
# 1    1
# 2    1
# Name: Survived, dtype: int64

# %%
# single [] bracket returns series as well
df['Survived'].head(3)
# Out:
# 0    0
# 1    1
# 2    1
# Name: Survived, dtype: int64

# %%
# double [[]] brackets return a dataframe
df[['Survived']].head(3)
# Out:
#    Survived
# 0         0
# 1         1
# 2         1

# %%
# [[]] return a dataframe
df[['Survived', 'Pclass']].head(3)
# Out:
#    Survived  Pclass
# 0         0       3
# 1         1       1
# 2         1       3

# %%
print(df['Survived'].head())
type(df['Survived'])
# Out:
# 0    0
# 1    1
# 2    1
# 3    1
# 4    0
# Name: Survived, dtype: int64
# pandas.core.series.Series

# %%
print(df[['Survived']].head())
type(df[['Survived']])
# Out:
#    Survived
# 0         0
# 1         1
# 2         1
# 3         1
# 4         0
# pandas.core.frame.DataFrame

# %%
# NaN = not a number
# NaT = not a data type
# attributes we dont use () eg shape, dtypes etc

df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# when we read our csv file and read into df, pandas automatically creates a indexed
df.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df.iloc[0:2,0:4]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name
# 0                            Braund, Mr. Owen Harris
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...

# %%
df.iloc[0:4]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S

# %%
df.iloc[2,4]
# Out:
# 'female'

# %%
df.iloc[1000:1004]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
# Position - Based Indexing - iloc[]
df.iloc[0].head()
# Out:
# PassengerId                          1
# Survived                             0
# Pclass                               3
# Name           Braund, Mr. Owen Harris
# Sex                               male
# Name: 0, dtype: object

# %%
# Label - Based indexing - loc()
df.loc[0:3, ['Age', 'Sex', 'Embarked']]
# Out:
#     Age     Sex Embarked
# 0  22.0    male        S
# 1  38.0  female        C
# 2  26.0  female        S
# 3  35.0  female        S

# %%
df.loc[0:9, ['Name', 'Fare']]
# Out:
#                                                 Name     Fare
# 0                            Braund, Mr. Owen Harris   7.2500
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  71.2833
# 2                             Heikkinen, Miss. Laina   7.9250
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  53.1000
# 4                           Allen, Mr. William Henry   8.0500
# 5                                   Moran, Mr. James   8.4583
# 6                            McCarthy, Mr. Timothy J  51.8625
# 7                     Palsson, Master. Gosta Leonard  21.0750
# 8  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  11.1333
# 9                Nasser, Mrs. Nicholas (Adele Achem)  30.0708

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
deck_df = df.copy()
deck_df.loc[0,'Deck'] = 'G'
deck_df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked Deck
# 0      0  A/5 21171   7.2500   NaN        S    G
# 1      0   PC 17599  71.2833   C85        C  NaN

# %%
deck_df.loc[0,'Embarked'] = 'Southampton'
deck_df.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin     Embarked Deck
# 0      0  A/5 21171   7.2500   NaN  Southampton    G
# 1      0   PC 17599  71.2833   C85            C  NaN

# %%
df.sort_values('Fare')
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 815          816         0       1                    Fry, Mr. Richard
# 806          807         0       1              Andrews, Mr. Thomas Jr
# 413          414         0       2      Cunningham, Mr. Alfred Fleming
# 481          482         0       2    Frost, Mr. Anthony Wood "Archie"
# 302          303         0       3     Johnson, Mr. William Cahoone Jr
# ..           ...       ...     ...                                 ...
# 438          439         0       1                   Fortune, Mr. Mark
# 341          342         1       1      Fortune, Miss. Alice Elizabeth
# 737          738         1       1              Lesurer, Mr. Gustave J
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 258          259         1       1                    Ward, Miss. Anna
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# ...
